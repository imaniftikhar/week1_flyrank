# %% [markdown]
# <a href="https://colab.research.google.com/github/imaniftikhar/week1_flyrank/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing Lane 2: Refresh / Content Opportunity Scoring. I selected this lane because it translates directly into a high-value, end-to-end classification and prioritization problem. Prioritizing content decay and identifying which pages are ripe for updates represents a classic machine learning framework where predictive models (like tree-based classifiers) can immediately outperform static, rule-based heuristics. It also aligns well with the starter repository pipeline infrastructure, giving me a solid foundation to iterate on feature engineering and model variants.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
# What decision does your work improve? It improves the editorial triage decision: specifically, determining which decaying or underperforming web pages should be assigned to human writers for a refresh versus which ones should be left alone.
#
# Who acts on it? Human content editors, strategy managers, and SEO copywriters.
#
# What does a wrong recommendation cost? A false positive (flagging a page for a refresh when it doesn't need one) wastes valuable editorial time and budget on content that already performs fine. A false negative (missing a severely decaying page) leads to compounding traffic losses and missed organic visibility to competitors

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# To get the 2–3 real numbers required for this section, you need to load the starter dataset. You can write a quick script in the code cell directly below this section to find your numbers

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Change this line in your notebook:
df = pd.read_csv('https://raw.githubusercontent.com/imaniftikhar/week1_flyrank/main/data/raw/content_refresh_anonymized.csv')

# 1. Total rows available for exploration
total_rows = len(df)
print(f"Total rows in playground dataset: {total_rows:,}")

# 2. Check the class balance or basic distribution of key metrics
# Let's see the average impressions or look for missing values in historical data
avg_impressions = df['impressions'].mean() if 'impressions' in df.columns else "N/A"
print(f"Average impressions per record: {avg_impressions}")

# 3. Look at your target variable or proxy flag distributions if available
# (e.g., viewing the head of the dataframe to pick a 3rd distinct signal flag)
print("\nFirst 3 rows of data:")
print(df.head(3))
# Out:
# Total rows in playground dataset: 30,000
# Average impressions per record: N/A
#
# First 3 rows of data:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
# 1     15562.0  ...     15000-25000  0.05          20.3             0.00
# 2     23643.0  ...     15000-25000  0.09          36.5             0.00
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
# What I can claim: This model provides an observed, directional, decision-support ranking tool. It flags pages showing structural and statistical patterns associated with historical content decay, helping prioritize human review queues based on measurable performance gaps.
#
# What I never will claim: This work does not provide causal proof of traffic loss, nor does it claim to "predict Google's proprietary algorithm." It maps raw performance signals to priority recommendations; it does not promise guaranteed ranking recoveries upon updating.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
